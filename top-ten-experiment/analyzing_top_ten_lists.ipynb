# %% [markdown]
# #Analyzing Shreddit's Q2 Top 5 voting
#
# This started out as a curiosity. I was interested in what I'd need to do to take a bunch of "Top X" lists, combine them and then ask questions to the data like, "What thing was number one the most?" or "If the votes are weighted, what does the actual top X look like?" I then remembered that Shreddit just did a voting. ;)
#
# This isn't a scientifically accurate analysis rooted in best practices. But I'm also just getting started with data analysis. So there's that.

# %%
# set up all the data for the rest of the notebook
import json
from collections import Counter
from itertools import chain
from IPython.display import HTML

def vote_table(votes):
    """Render a crappy HTML table for easy display. I'd use Pandas, but that seems like
    complete overkill for this simple task.
    """
    base_table = """
    <table>
        <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
        {}
    </table>
    """
    
    base_row = "<tr><td>{0}</td><td>{1}</td><td>{2}</td></tr>"
    vote_rows = [base_row.format(idx, name, vote) for idx, (name, vote) in enumerate(votes, 1)]
    return HTML(base_table.format('\n'.join(vote_rows)))

with open('shreddit_q2_votes.json', 'r') as fh:
    ballots = json.load(fh)

with open('tallied_votes.json', 'r') as fh:
    tallied = Counter(json.load(fh))

equal_placement_ballots = Counter(chain.from_iterable(ballots))

# %% [markdown]
# ##Equal Placement Ballots
#
# The equal placement ballot assumes that any position on the ballot is equal to any other. And given that this how the voting was designed, it makes the most sense to look at this first. There are some differences, but given that /u/kaptain_carbon was tallying by hand, and I manually copy-pasted ballots (regex is hard) and then had to manually massage some data (fixing names and the like), differences are to be expected. Another note, all the data in my set is lower cased in an effort to normalize to make the data more accurate. My analysis also includes submissions from *after* voting was closed, mostly because I was too lazy to check dates.
#
# I'm also playing fast and loose with items that end up with the same total, rather than doing the "right thing" and marking them at the same position. So, there's that.
#
# Here's the top ten of the table in the post.

# %%
vote_table(tallied.most_common(10))
# Out:
#     <table>
#         <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
#         <tr><td>1</td><td>Sulphur Aeon - Gateway to the Antisphere</td><td>33</td></tr>
# <tr><td>2</td><td>Misþyrming - Söngvar elds og óreiðu</td><td>33</td></tr>
# <tr><td>3</td><td>Leviathan - Scar Sighted</td><td>28</td></tr>
# <tr><td>4</td><td>Blind Guardian - Beyond the Red Mirror</td><td>28</td></tr>
# <tr><td>5</td><td>Elder - Lore</td><td>25</td></tr>
# <tr><td>6</td><td>Enslaved - In Times</td><td>25</td></tr>
# <tr><td>7</td><td>High on Fire - Lumineferous</td><td>16</td></tr>
# <tr><td>8</td><td>Melechesh - Enki</td><td>15</td></tr>
# <tr><td>9</td><td>Visigoth - The Revenant King</td><td>15</td></tr>
# <tr><td>10</td><td>Macabre Omen - Gods of War - At War</td><td>14</td></tr>
#     </table>

# %% [markdown]
# And here's the top ten from my computed tally:

# %%
vote_table(equal_placement_ballots.most_common(10))
# Out:
#     <table>
#         <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
#         <tr><td>1</td><td>misþyrming - söngvar elds og óreiðu</td><td>30</td></tr>
# <tr><td>2</td><td>sulphur aeon - gateway to the antisphere</td><td>29</td></tr>
# <tr><td>3</td><td>blind guardian - beyond the red mirror</td><td>27</td></tr>
# <tr><td>4</td><td>leviathan - scar sighted</td><td>25</td></tr>
# <tr><td>5</td><td>elder - lore</td><td>25</td></tr>
# <tr><td>6</td><td>enslaved - in times</td><td>24</td></tr>
# <tr><td>7</td><td>deathhammer - evil power</td><td>16</td></tr>
# <tr><td>8</td><td>melechesh - enki</td><td>15</td></tr>
# <tr><td>9</td><td>visigoth - the revenant king</td><td>15</td></tr>
# <tr><td>10</td><td>obsequiae - aria of vernal tombs</td><td>15</td></tr>
#     </table>

# %% [markdown]
# ##Weighted Tally Ballot
#
# But that's boring. What if we pretended for a second that everyone submitted a ballot where the albums were actually ranked one through five. What would the top ten look like then? There's a few ways to figure this one out. Initially, my thought was to provide a number 1 to 5 based on position to each vote and then find the lowest sum. However, the problem is that an item that only appears once will be considered the most preferred. That won't work. But going backwards from five to one for each item and then finding the largest total probably would:

# %%
weighted_ballot = Counter()

for ballot in ballots:
    for item, weight in zip(ballot, range(5, 0, -1)):
        weighted_ballot[item] += weight

# %% [markdown]
# This handles the situation where a ballot may not be full (five votes), which make up a surpsingly non trival amount of the ballots:

# %%
sum(1 for _ in filter(lambda x: len(x) < 5, ballots)) / len(ballots)
# Out:
# 0.1125

# %% [markdown]
# Anyways, what does a top ten for weighted votes end up looking like?

# %%
vote_table(weighted_ballot.most_common(10))
# Out:
#     <table>
#         <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
#         <tr><td>1</td><td>misþyrming - söngvar elds og óreiðu</td><td>105</td></tr>
# <tr><td>2</td><td>sulphur aeon - gateway to the antisphere</td><td>100</td></tr>
# <tr><td>3</td><td>leviathan - scar sighted</td><td>98</td></tr>
# <tr><td>4</td><td>blind guardian - beyond the red mirror</td><td>93</td></tr>
# <tr><td>5</td><td>elder - lore</td><td>90</td></tr>
# <tr><td>6</td><td>enslaved - in times</td><td>76</td></tr>
# <tr><td>7</td><td>visigoth - the revenant king</td><td>52</td></tr>
# <tr><td>8</td><td>melechesh - enki</td><td>50</td></tr>
# <tr><td>9</td><td>deathhammer - evil power</td><td>50</td></tr>
# <tr><td>10</td><td>obsequiae - aria of vernal tombs</td><td>49</td></tr>
#     </table>

# %% [markdown]
# Hm, it's not actually all the different. Some bands move around a little bit, Deathhammer moves into the top ten using this method. But overall, the general spread is pretty much the same.

# %% [markdown]
# It's also interesting to look at the difference in position from the weighted tally vs the way it's done in the thread. There's major differences between the two due to the voting difference and from including submissions from after voting expired. There's also a missing band. :?

# %%
regular_tally_spots = {name.lower(): pos for pos, (name, _) in enumerate(tallied.most_common(), 1)}

base_table = """
<table>
    <tr><td>Album</td><td>Regular Spot</td><td>Weighted Spot</td></tr>
    {}
</table>
"""
base_row = "<tr><td>{0}</td><td>{1}</td><td>{2}</td></tr>"

rows = [base_row.format(name, regular_tally_spots[name], pos) 
        for pos, (name, _) in enumerate(weighted_ballot.most_common(), 1)
        # some albums didn't make it, like Arcturian D:
        if name in regular_tally_spots]

HTML(base_table.format('\n'.join(rows)))
# Out:
# <table>
#     <tr><td>Album</td><td>Regular Spot</td><td>Weighted Spot</td></tr>
#     <tr><td>misþyrming - söngvar elds og óreiðu</td><td>2</td><td>1</td></tr>
# <tr><td>sulphur aeon - gateway to the antisphere</td><td>1</td><td>2</td></tr>
# <tr><td>leviathan - scar sighted</td><td>3</td><td>3</td></tr>
# <tr><td>blind guardian - beyond the red mirror</td><td>4</td><td>4</td></tr>
# <tr><td>elder - lore</td><td>5</td><td>5</td></tr>
# <tr><td>enslaved - in times</td><td>6</td><td>6</td></tr>
# <tr><td>visigoth - the revenant king</td><td>9</td><td>7</td></tr>
# <tr><td>melechesh - enki</td><td>8</td><td>8</td></tr>
# <tr><td>deathhammer - evil power</td><td>22</td><td>9</td></tr>
# <tr><td>obsequiae - aria of vernal tombs</td><td>13</td><td>10</td></tr>
# <tr><td>ghost bath - moonlover</td><td>14</td><td>11</td></tr>
# <tr><td>macabre omen - gods of war - at war</td><td>10</td><td>12</td></tr>
# <tr><td>high on fire - lumineferous</td><td>7</td><td>13</td></tr>
# <tr><td>crypt sermon - out of the garden</td><td>28</td><td>14</td></tr>
# <tr><td>bell witch - four phantoms</td><td>12</td><td>15</td></tr>
# <tr><td>drudkh - a furrow cut short</td><td>21</td><td>16</td></tr>
# <tr><td>cloud rat - qliphoth</td><td>29</td><td>17</td></tr>
# <tr><td>a forest of stars - beware the sword you cannot see</td><td>15</td><td>18</td></tr>
# <tr><td>akhlys - the dreaming i</td><td>18</td><td>19</td></tr>
# <tr><td>caedes cruenta - ερείπια ψυχών</td><td>23</td><td>20</td></tr>
# <tr><td>tribulation - children of the night</td><td>11</td><td>21</td></tr>
# <tr><td>bosse de nage - all fours</td><td>24</td><td>22</td></tr>
# <tr><td>ensiferum - one man army</td><td>31</td><td>23</td></tr>
# <tr><td>marduk - frontschwein</td><td>16</td><td>24</td></tr>
# <tr><td>napalm death - apex predator -- easy meat</td><td>20</td><td>25</td></tr>
# <tr><td>enforcer - from beyond</td><td>17</td><td>26</td></tr>
# <tr><td>false - untitled</td><td>32</td><td>27</td></tr>
# <tr><td>midnight odyssey - shards of silver fade</td><td>30</td><td>28</td></tr>
# <tr><td>nocternity  - harps of the ancient temples</td><td>26</td><td>29</td></tr>
# <tr><td>entrails - obliteration</td><td>34</td><td>30</td></tr>
# <tr><td>monolord - vænir</td><td>25</td><td>31</td></tr>
# <tr><td>judicator - at the expense of humanity</td><td>43</td><td>32</td></tr>
# <tr><td>archgoat - the apocalyptic triumphator</td><td>36</td><td>33</td></tr>
# <tr><td>abyssal - antikatastaseis</td><td>37</td><td>35</td></tr>
# <tr><td>ethereal shroud - they became falling ash</td><td>38</td><td>36</td></tr>
# <tr><td>gruesome - savage land</td><td>33</td><td>37</td></tr>
# <tr><td>desolate shrine - heart of the netherworld</td><td>39</td><td>38</td></tr>
# <tr><td>wilderun - sleep at the edge of the earth</td><td>44</td><td>39</td></tr>
# <tr><td>sylosis - dormant heart</td><td>41</td><td>41</td></tr>
# <tr><td>vattnet viskar - settler</td><td>19</td><td>43</td></tr>
# <tr><td>leprous - the congregation</td><td>47</td><td>46</td></tr>
# <tr><td>noisem - blossoming decay</td><td>40</td><td>49</td></tr>
# <tr><td>gouge - beyond death</td><td>45</td><td>50</td></tr>
# <tr><td>chapel of disease - the mysterious ways of repetitive art</td><td>35</td><td>53</td></tr>
# <tr><td>dødheimsgard - a umbra omega</td><td>46</td><td>70</td></tr>
# <tr><td>hæthen - shaped by aeolian winds</td><td>42</td><td>86</td></tr>
# <tr><td>unrest - grindcore</td><td>49</td><td>98</td></tr>
# <tr><td>hic iacet - the cosmic trance into void</td><td>51</td><td>104</td></tr>
# <tr><td>lord dying - poised altars</td><td>50</td><td>106</td></tr>
# <tr><td>devouring star - through lung and heart</td><td>48</td><td>183</td></tr>
# </table>

# %% [markdown]
# ##What album appeared at number one most often?
#
# Another question I've been pondering is, "How do you figure out what thing appears at number one most often?" Again, this is assuming everyone submitted a ballot with the intention of it being read as ranked. Turns out, doing this isn't that hard either:

# %%
number_one = Counter([b[0] for b in ballots]) 
vote_table(number_one.most_common(10))
# Out:
#     <table>
#         <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
#         <tr><td>1</td><td>leviathan - scar sighted</td><td>12</td></tr>
# <tr><td>2</td><td>sulphur aeon - gateway to the antisphere</td><td>11</td></tr>
# <tr><td>3</td><td>elder - lore</td><td>10</td></tr>
# <tr><td>4</td><td>misþyrming - söngvar elds og óreiðu</td><td>10</td></tr>
# <tr><td>5</td><td>blind guardian - beyond the red mirror</td><td>9</td></tr>
# <tr><td>6</td><td>enslaved - in times</td><td>6</td></tr>
# <tr><td>7</td><td>visigoth - the revenant king</td><td>5</td></tr>
# <tr><td>8</td><td>melechesh - enki</td><td>5</td></tr>
# <tr><td>9</td><td>high on fire - lumineferous</td><td>4</td></tr>
# <tr><td>10</td><td>deathhammer - evil power</td><td>4</td></tr>
#     </table>

# %% [markdown]
# This paints a slightly different picture of the top ten. While the names are largely the same, Scar Sighted was thought of as the top album most often, despite being at two or three through the other methods. And Misþyrming is at three (okay, "2", again fast and loose with numbering) despite being the solid top choice for all other methods.

# %% [markdown]
# ##The Take Away
# There's lot of different ways to look at the ballots and different ways to tally them. Weighted voting is certainly interesting than straight up counting votes the usual way.
#
# Originally, I had wondered if something like something along the lines of Instant Runoff Voting or data processing packages like Panadas, Numpy or SciPy would be needed. But for basic prodding and poking, it turns out the stdlib is just fine.
#
# Also: a lot of awesome music I haven't listened to at all this year (been tied up with [Peace is the Mission](https://www.youtube.com/watch?v=Z4TwbrihsNw) the last few weeks, too, sorry guys).

# %% [markdown]
# ##The full tables
#
# Because someone will ask for them, here's the full tables from my analysis:

# %%
#regular tallying
vote_table(equal_placement_ballots.most_common())
# Out:
#     <table>
#         <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
#         <tr><td>1</td><td>misþyrming - söngvar elds og óreiðu</td><td>30</td></tr>
# <tr><td>2</td><td>sulphur aeon - gateway to the antisphere</td><td>29</td></tr>
# <tr><td>3</td><td>blind guardian - beyond the red mirror</td><td>27</td></tr>
# <tr><td>4</td><td>leviathan - scar sighted</td><td>25</td></tr>
# <tr><td>5</td><td>elder - lore</td><td>25</td></tr>
# <tr><td>6</td><td>enslaved - in times</td><td>24</td></tr>
# <tr><td>7</td><td>deathhammer - evil power</td><td>16</td></tr>
# <tr><td>8</td><td>melechesh - enki</td><td>15</td></tr>
# <tr><td>9</td><td>visigoth - the revenant king</td><td>15</td></tr>
# <tr><td>10</td><td>obsequiae - aria of vernal tombs</td><td>15</td></tr>
# <tr><td>11</td><td>macabre omen - gods of war - at war</td><td>13</td></tr>
# <tr><td>12</td><td>ghost bath - moonlover</td><td>12</td></tr>
# <tr><td>13</td><td>high on fire - lumineferous</td><td>12</td></tr>
# <tr><td>14</td><td>tribulation - children of the night</td><td>10</td></tr>
# <tr><td>15</td><td>drudkh - a furrow cut short</td><td>10</td></tr>
# <tr><td>16</td><td>bell witch - four phantoms</td><td>10</td></tr>
# <tr><td>17</td><td>a forest of stars - beware the sword you cannot see</td><td>10</td></tr>
# <tr><td>18</td><td>marduk - frontschwein</td><td>10</td></tr>
# <tr><td>19</td><td>napalm death - apex predator -- easy meat</td><td>10</td></tr>
# <tr><td>20</td><td>enforcer - from beyond</td><td>10</td></tr>
# <tr><td>21</td><td>akhlys - the dreaming i</td><td>9</td></tr>
# <tr><td>22</td><td>crypt sermon - out of the garden</td><td>9</td></tr>
# <tr><td>23</td><td>cloud rat - qliphoth</td><td>8</td></tr>
# <tr><td>24</td><td>nocternity  - harps of the ancient temples</td><td>8</td></tr>
# <tr><td>25</td><td>bosse de nage - all fours</td><td>8</td></tr>
# <tr><td>26</td><td>vattnet viskar - settler</td><td>8</td></tr>
# <tr><td>27</td><td>false - untitled</td><td>8</td></tr>
# <tr><td>28</td><td>caedes cruenta - ερείπια ψυχών</td><td>7</td></tr>
# <tr><td>29</td><td>gruesome - savage land</td><td>7</td></tr>
# <tr><td>30</td><td>ensiferum - one man army</td><td>7</td></tr>
# <tr><td>31</td><td>entrails - obliteration</td><td>7</td></tr>
# <tr><td>32</td><td>midnight odyssey - shards of silver fade</td><td>6</td></tr>
# <tr><td>33</td><td>monolord - vænir</td><td>6</td></tr>
# <tr><td>34</td><td>desolate shrine - heart of the netherworld</td><td>6</td></tr>
# <tr><td>35</td><td>abyssal - antikatastaseis</td><td>6</td></tr>
# <tr><td>36</td><td>ethereal shroud - they became falling ash</td><td>6</td></tr>
# <tr><td>37</td><td>judicator - at the expense of humanity</td><td>5</td></tr>
# <tr><td>38</td><td>kamelot - haven</td><td>5</td></tr>
# <tr><td>39</td><td>archgoat - the apocalyptic triumphator</td><td>5</td></tr>
# <tr><td>40</td><td>paradise lost - the plague within</td><td>5</td></tr>
# <tr><td>41</td><td>sylosis - dormant heart</td><td>5</td></tr>
# <tr><td>42</td><td>barren earth - on lonely towers</td><td>5</td></tr>
# <tr><td>43</td><td>arcturus - arcturian</td><td>5</td></tr>
# <tr><td>44</td><td>chapel of disease - the mysterious ways of repetitive art</td><td>5</td></tr>
# <tr><td>45</td><td>wilderun - sleep at the edge of the earth</td><td>5</td></tr>
# <tr><td>46</td><td>downfall of nur - umbras de barbagia</td><td>4</td></tr>
# <tr><td>47</td><td>noisem - blossoming decay</td><td>4</td></tr>
# <tr><td>48</td><td>gouge - beyond death</td><td>4</td></tr>
# <tr><td>49</td><td>sumac - the deal</td><td>4</td></tr>
# <tr><td>50</td><td>peste noire - la chaise-dyable</td><td>4</td></tr>
# <tr><td>51</td><td>mefitic - woes of mortal devotion</td><td>4</td></tr>
# <tr><td>52</td><td>leprous - the congregation</td><td>4</td></tr>
# <tr><td>53</td><td>necrowretch - with serpents scourge</td><td>3</td></tr>
# <tr><td>54</td><td>moonspell - extinct</td><td>3</td></tr>
# <tr><td>55</td><td>minsk - the crash and the draw</td><td>3</td></tr>
# <tr><td>56</td><td>perdition temple - the tempter's victorious</td><td>3</td></tr>
# <tr><td>57</td><td>ranger - where evil dwells</td><td>3</td></tr>
# <tr><td>58</td><td>glaciation - sur les falaises de marbre</td><td>3</td></tr>
# <tr><td>59</td><td>nightwish - endless forms most beautiful</td><td>3</td></tr>
# <tr><td>60</td><td>urfaust - apparitions</td><td>3</td></tr>
# <tr><td>61</td><td>dødheimsgard - a umbra omega</td><td>3</td></tr>
# <tr><td>62</td><td>unrest - grindcore</td><td>3</td></tr>
# <tr><td>63</td><td>orden ogan - ravenhead</td><td>3</td></tr>
# <tr><td>64</td><td>sarpanitum - blessed be my brothers</td><td>3</td></tr>
# <tr><td>65</td><td>drowning the light - from the abyss</td><td>2</td></tr>
# <tr><td>66</td><td>imperial triumphant - abyssal gods</td><td>2</td></tr>
# <tr><td>67</td><td>bloodlust - cultus diaboli</td><td>2</td></tr>
# <tr><td>68</td><td>cain's offering - stormcrow</td><td>2</td></tr>
# <tr><td>69</td><td>xibalba - tierra y libertad</td><td>2</td></tr>
# <tr><td>70</td><td>encyrcle - encyrcle</td><td>2</td></tr>
# <tr><td>71</td><td>trial - vessel</td><td>2</td></tr>
# <tr><td>72</td><td>devouring star - through lung and heart</td><td>2</td></tr>
# <tr><td>73</td><td>hæthen - shaped by aeolian winds</td><td>2</td></tr>
# <tr><td>74</td><td>mastery - valis</td><td>2</td></tr>
# <tr><td>75</td><td>black howling - o sangue e a terra</td><td>2</td></tr>
# <tr><td>76</td><td>paradise lost - the plauge within</td><td>2</td></tr>
# <tr><td>77</td><td>inculter - persisting devolution</td><td>2</td></tr>
# <tr><td>78</td><td>violet cold - desperate dreams</td><td>2</td></tr>
# <tr><td>79</td><td>archivist - archivist</td><td>2</td></tr>
# <tr><td>80</td><td>tau cross - tau cross</td><td>2</td></tr>
# <tr><td>81</td><td>undersmile - anhedonia</td><td>2</td></tr>
# <tr><td>82</td><td>vallendusk - homeward path</td><td>2</td></tr>
# <tr><td>83</td><td>tempel - the moon lit our path</td><td>2</td></tr>
# <tr><td>84</td><td>helloween - my god given right</td><td>2</td></tr>
# <tr><td>85</td><td>alkaloid - the malkuth grimoire</td><td>2</td></tr>
# <tr><td>86</td><td>psycroptic - psycroptic</td><td>2</td></tr>
# <tr><td>87</td><td>clandestine blaze - new golgotha rising</td><td>2</td></tr>
# <tr><td>88</td><td>witchtower - witchtower</td><td>1</td></tr>
# <tr><td>89</td><td>valborg - romantik</td><td>1</td></tr>
# <tr><td>90</td><td>secret sphere - a time never come</td><td>1</td></tr>
# <tr><td>91</td><td>misblerbling - songvar yadda yadda</td><td>1</td></tr>
# <tr><td>92</td><td>forefather - curse of the qwelled</td><td>1</td></tr>
# <tr><td>93</td><td>lord dying - poised altars</td><td>1</td></tr>
# <tr><td>94</td><td>hollow haze - memories of an ancient time</td><td>1</td></tr>
# <tr><td>95</td><td>kjeld - skym</td><td>1</td></tr>
# <tr><td>96</td><td>jarun - pod niebem utkanym z popiołu</td><td>1</td></tr>
# <tr><td>97</td><td>aktor - paranoia</td><td>1</td></tr>
# <tr><td>98</td><td>wicked inquisition - wicked inquisition</td><td>1</td></tr>
# <tr><td>99</td><td>chalice of blood - helig, helig, helig</td><td>1</td></tr>
# <tr><td>100</td><td>acid king - middle of nowhere, center of everywhere</td><td>1</td></tr>
# <tr><td>101</td><td>jupiter - the history of genes</td><td>1</td></tr>
# <tr><td>102</td><td>outre - ghost chants</td><td>1</td></tr>
# <tr><td>103</td><td>jøtnarr - burn and bury</td><td>1</td></tr>
# <tr><td>104</td><td>ninkharsag - blood of celestial kings</td><td>1</td></tr>
# <tr><td>105</td><td>carach angren - this is no fairytale</td><td>1</td></tr>
# <tr><td>106</td><td>grimoire - l'aorasie des spectres rêveurs</td><td>1</td></tr>
# <tr><td>107</td><td>rolo tomassi - grievances</td><td>1</td></tr>
# <tr><td>108</td><td>gospel of the witches - salem's wounds</td><td>1</td></tr>
# <tr><td>109</td><td>secrets of the sky - pathway</td><td>1</td></tr>
# <tr><td>110</td><td>pyrrhon - growth without end</td><td>1</td></tr>
# <tr><td>111</td><td>waltari - you are</td><td>1</td></tr>
# <tr><td>112</td><td>sigh - graveword</td><td>1</td></tr>
# <tr><td>113</td><td>reign of fury - death be thy shepherd</td><td>1</td></tr>
# <tr><td>114</td><td>ithaqua - initiation to obscure mysteries (demo i know, but fuck it)</td><td>

# %%
#weighted ballot
vote_table(weighted_ballot.most_common())
# Out:
#     <table>
#         <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
#         <tr><td>1</td><td>misþyrming - söngvar elds og óreiðu</td><td>105</td></tr>
# <tr><td>2</td><td>sulphur aeon - gateway to the antisphere</td><td>100</td></tr>
# <tr><td>3</td><td>leviathan - scar sighted</td><td>98</td></tr>
# <tr><td>4</td><td>blind guardian - beyond the red mirror</td><td>93</td></tr>
# <tr><td>5</td><td>elder - lore</td><td>90</td></tr>
# <tr><td>6</td><td>enslaved - in times</td><td>76</td></tr>
# <tr><td>7</td><td>visigoth - the revenant king</td><td>52</td></tr>
# <tr><td>8</td><td>melechesh - enki</td><td>50</td></tr>
# <tr><td>9</td><td>deathhammer - evil power</td><td>50</td></tr>
# <tr><td>10</td><td>obsequiae - aria of vernal tombs</td><td>49</td></tr>
# <tr><td>11</td><td>ghost bath - moonlover</td><td>40</td></tr>
# <tr><td>12</td><td>macabre omen - gods of war - at war</td><td>38</td></tr>
# <tr><td>13</td><td>high on fire - lumineferous</td><td>37</td></tr>
# <tr><td>14</td><td>crypt sermon - out of the garden</td><td>34</td></tr>
# <tr><td>15</td><td>bell witch - four phantoms</td><td>31</td></tr>
# <tr><td>16</td><td>drudkh - a furrow cut short</td><td>30</td></tr>
# <tr><td>17</td><td>cloud rat - qliphoth</td><td>29</td></tr>
# <tr><td>18</td><td>a forest of stars - beware the sword you cannot see</td><td>29</td></tr>
# <tr><td>19</td><td>akhlys - the dreaming i</td><td>29</td></tr>
# <tr><td>20</td><td>caedes cruenta - ερείπια ψυχών</td><td>28</td></tr>
# <tr><td>21</td><td>tribulation - children of the night</td><td>28</td></tr>
# <tr><td>22</td><td>bosse de nage - all fours</td><td>26</td></tr>
# <tr><td>23</td><td>ensiferum - one man army</td><td>26</td></tr>
# <tr><td>24</td><td>marduk - frontschwein</td><td>26</td></tr>
# <tr><td>25</td><td>napalm death - apex predator -- easy meat</td><td>26</td></tr>
# <tr><td>26</td><td>enforcer - from beyond</td><td>25</td></tr>
# <tr><td>27</td><td>false - untitled</td><td>24</td></tr>
# <tr><td>28</td><td>midnight odyssey - shards of silver fade</td><td>21</td></tr>
# <tr><td>29</td><td>nocternity  - harps of the ancient temples</td><td>21</td></tr>
# <tr><td>30</td><td>entrails - obliteration</td><td>20</td></tr>
# <tr><td>31</td><td>monolord - vænir</td><td>19</td></tr>
# <tr><td>32</td><td>judicator - at the expense of humanity</td><td>18</td></tr>
# <tr><td>33</td><td>archgoat - the apocalyptic triumphator</td><td>17</td></tr>
# <tr><td>34</td><td>arcturus - arcturian</td><td>17</td></tr>
# <tr><td>35</td><td>abyssal - antikatastaseis</td><td>17</td></tr>
# <tr><td>36</td><td>ethereal shroud - they became falling ash</td><td>17</td></tr>
# <tr><td>37</td><td>gruesome - savage land</td><td>16</td></tr>
# <tr><td>38</td><td>desolate shrine - heart of the netherworld</td><td>16</td></tr>
# <tr><td>39</td><td>wilderun - sleep at the edge of the earth</td><td>16</td></tr>
# <tr><td>40</td><td>kamelot - haven</td><td>15</td></tr>
# <tr><td>41</td><td>sylosis - dormant heart</td><td>15</td></tr>
# <tr><td>42</td><td>barren earth - on lonely towers</td><td>15</td></tr>
# <tr><td>43</td><td>vattnet viskar - settler</td><td>15</td></tr>
# <tr><td>44</td><td>peste noire - la chaise-dyable</td><td>13</td></tr>
# <tr><td>45</td><td>mefitic - woes of mortal devotion</td><td>12</td></tr>
# <tr><td>46</td><td>leprous - the congregation</td><td>11</td></tr>
# <tr><td>47</td><td>downfall of nur - umbras de barbagia</td><td>10</td></tr>
# <tr><td>48</td><td>paradise lost - the plague within</td><td>10</td></tr>
# <tr><td>49</td><td>noisem - blossoming decay</td><td>10</td></tr>
# <tr><td>50</td><td>gouge - beyond death</td><td>10</td></tr>
# <tr><td>51</td><td>sumac - the deal</td><td>10</td></tr>
# <tr><td>52</td><td>glaciation - sur les falaises de marbre</td><td>10</td></tr>
# <tr><td>53</td><td>chapel of disease - the mysterious ways of repetitive art</td><td>10</td></tr>
# <tr><td>54</td><td>tempel - the moon lit our path</td><td>10</td></tr>
# <tr><td>55</td><td>orden ogan - ravenhead</td><td>10</td></tr>
# <tr><td>56</td><td>moonspell - extinct</td><td>9</td></tr>
# <tr><td>57</td><td>perdition temple - the tempter's victorious</td><td>9</td></tr>
# <tr><td>58</td><td>violet cold - desperate dreams</td><td>9</td></tr>
# <tr><td>59</td><td>sarpanitum - blessed be my brothers</td><td>9</td></tr>
# <tr><td>60</td><td>minsk - the crash and the draw</td><td>8</td></tr>
# <tr><td>61</td><td>black howling - o sangue e a terra</td><td>8</td></tr>
# <tr><td>62</td><td>clandestine blaze - new golgotha rising</td><td>8</td></tr>
# <tr><td>63</td><td>necrowretch - with serpents scourge</td><td>7</td></tr>
# <tr><td>64</td><td>xibalba - tierra y libertad</td><td>7</td></tr>
# <tr><td>65</td><td>mastery - valis</td><td>7</td></tr>
# <tr><td>66</td><td>vallendusk - homeward path</td><td>7</td></tr>
# <tr><td>67</td><td>imperial triumphant - abyssal gods</td><td>6</td></tr>
# <tr><td>68</td><td>bloodlust - cultus diaboli</td><td>6</td></tr>
# <tr><td>69</td><td>cain's offering - stormcrow</td><td>6</td></tr>
# <tr><td>70</td><td>dødheimsgard - a umbra omega</td><td>6</td></tr>
# <tr><td>71</td><td>helloween - my god given right</td><td>6</td></tr>
# <tr><td>72</td><td>alkaloid - the malkuth grimoire</td><td>6</td></tr>
# <tr><td>73</td><td>psycroptic - psycroptic</td><td>6</td></tr>
# <tr><td>74</td><td>forefather - curse of the qwelled</td><td>5</td></tr>
# <tr><td>75</td><td>drowning the light - from the abyss</td><td>5</td></tr>
# <tr><td>76</td><td>hollow haze - memories of an ancient time</td><td>5</td></tr>
# <tr><td>77</td><td>kjeld - skym</td><td>5</td></tr>
# <tr><td>78</td><td>carach angren - this is no fairytale</td><td>5</td></tr>
# <tr><td>79</td><td>gospel of the witches - salem's wounds</td><td>5</td></tr>
# <tr><td>80</td><td>trial - vessel</td><td>5</td></tr>
# <tr><td>81</td><td>ancient wind - the chosen slain</td><td>5</td></tr>
# <tr><td>82</td><td>cendra - 666 bastards</td><td>5</td></tr>
# <tr><td>83</td><td>ufomammut - ecate</td><td>5</td></tr>
# <tr><td>84</td><td>sickening horror - overflow</td><td>5</td></tr>
# <tr><td>85</td><td>a secret revealed - the bleakness</td><td>5</td></tr>
# <tr><td>86</td><td>hæthen - shaped by aeolian winds</td><td>5</td></tr>
# <tr><td>87</td><td>die like gentlemen - five easy lies</td><td>5</td></tr>
# <tr><td>88</td><td>the armed - untitled</td><td>5</td></tr>
# <tr><td>89</td><td>kêres - battle secrets</td><td>5</td></tr>
# <tr><td>90</td><td>native construct - quiet world</td><td>5</td></tr>
# <tr><td>91</td><td>royal thunder - crooked doors</td><td>5</td></tr>
# <tr><td>92</td><td>nightwish - endless forms most beautiful</td><td>5</td></tr>
# <tr><td>93</td><td>a sulphur aeon - gateway to the antisphere</td><td>5</td></tr>
# <tr><td>94</td><td>urfaust - apparitions</td><td>5</td></tr>
# <tr><td>95</td><td>evil invaders - pulses of pleasure</td><td>5</td></tr>
# <tr><td>96</td><td>archivist - archivist</td><td>5</td></tr>
# <tr><td>97</td><td>perihelion - infinite decay</td><td>5</td></tr>
# <tr><td>98</td><td>unrest - grindcore</td><td>5</td></tr>
# <tr><td>99</td><td>arcane - known/learned</td><td>5</td></tr>
# <tr><td>100</td><td>paganland - fatherland</td><td>5</td></tr>
# <tr><td>101</td><td>galar - de jgenlevende</td><td>5</td></tr>
# <tr><td>102</td><td>the crinn - shadow breather</td><td>5</td></tr>
# <tr><td>103</td><td>solefald - worldmetal - kosmopolis sud</td><td>5</td></tr>
# <tr><td>104</td><td>hic iacet - the cosmic trance into void</td><td>5</td></tr>
# <tr><td>105</td><td>skinless - only the ruthless remain</td><td>5</td></tr>
# <tr><td>106</td><td>lord dying - poised altars</td><td>4</td></tr>
# <tr><td>107</td><td>jøtnarr - burn and bury</td><td>4</td></tr>
# <tr><td>108</td><td>grimoire - l'aorasie des spectres rêveurs</td><td>4</td></tr>
# <tr><td>109</td><td>rolo tomassi - grievances</td><td>4</td></tr>
# <tr><td>110</td><td>secrets of the sky - pathway</td><td>4</td></tr>
# <tr><td>111</td><td>encyrcle - encyrcle</td><td>4</td></tr>
# <tr><td>112</td><td>ithaqua - initiation to obscure mysteries (demo i know, but fuck it)</td><td>4</td></tr>
# <tr><td>113</td><td>utstøtt - hjørungavågr</td><td>4</td></tr>
# <tr><td>114</td><td>lustre - blossom</td><t

# %%
#number one count
vote_table(number_one.most_common())
# Out:
#     <table>
#         <tr><td>Position</td><td>Album</td><td>Votes</td></tr>
#         <tr><td>1</td><td>leviathan - scar sighted</td><td>12</td></tr>
# <tr><td>2</td><td>sulphur aeon - gateway to the antisphere</td><td>11</td></tr>
# <tr><td>3</td><td>elder - lore</td><td>10</td></tr>
# <tr><td>4</td><td>misþyrming - söngvar elds og óreiðu</td><td>10</td></tr>
# <tr><td>5</td><td>blind guardian - beyond the red mirror</td><td>9</td></tr>
# <tr><td>6</td><td>enslaved - in times</td><td>6</td></tr>
# <tr><td>7</td><td>visigoth - the revenant king</td><td>5</td></tr>
# <tr><td>8</td><td>melechesh - enki</td><td>5</td></tr>
# <tr><td>9</td><td>high on fire - lumineferous</td><td>4</td></tr>
# <tr><td>10</td><td>deathhammer - evil power</td><td>4</td></tr>
# <tr><td>11</td><td>ghost bath - moonlover</td><td>4</td></tr>
# <tr><td>12</td><td>caedes cruenta - ερείπια ψυχών</td><td>4</td></tr>
# <tr><td>13</td><td>crypt sermon - out of the garden</td><td>3</td></tr>
# <tr><td>14</td><td>bosse de nage - all fours</td><td>3</td></tr>
# <tr><td>15</td><td>ensiferum - one man army</td><td>3</td></tr>
# <tr><td>16</td><td>cloud rat - qliphoth</td><td>2</td></tr>
# <tr><td>17</td><td>tempel - the moon lit our path</td><td>2</td></tr>
# <tr><td>18</td><td>midnight odyssey - shards of silver fade</td><td>2</td></tr>
# <tr><td>19</td><td>nocternity  - harps of the ancient temples</td><td>2</td></tr>
# <tr><td>20</td><td>monolord - vænir</td><td>2</td></tr>
# <tr><td>21</td><td>a forest of stars - beware the sword you cannot see</td><td>2</td></tr>
# <tr><td>22</td><td>arcturus - arcturian</td><td>2</td></tr>
# <tr><td>23</td><td>drudkh - a furrow cut short</td><td>2</td></tr>
# <tr><td>24</td><td>violet cold - desperate dreams</td><td>1</td></tr>
# <tr><td>25</td><td>mastery - valis</td><td>1</td></tr>
# <tr><td>26</td><td>native construct - quiet world</td><td>1</td></tr>
# <tr><td>27</td><td>forefather - curse of the qwelled</td><td>1</td></tr>
# <tr><td>28</td><td>obsequiae - aria of vernal tombs</td><td>1</td></tr>
# <tr><td>29</td><td>abyssal - antikatastaseis</td><td>1</td></tr>
# <tr><td>30</td><td>peste noire - la chaise-dyable</td><td>1</td></tr>
# <tr><td>31</td><td>necrowretch - with serpents scourge</td><td>1</td></tr>
# <tr><td>32</td><td>the armed - untitled</td><td>1</td></tr>
# <tr><td>33</td><td>hollow haze - memories of an ancient time</td><td>1</td></tr>
# <tr><td>34</td><td>galar - de jgenlevende</td><td>1</td></tr>
# <tr><td>35</td><td>black howling - o sangue e a terra</td><td>1</td></tr>
# <tr><td>36</td><td>imperial triumphant - abyssal gods</td><td>1</td></tr>
# <tr><td>37</td><td>sylosis - dormant heart</td><td>1</td></tr>
# <tr><td>38</td><td>sickening horror - overflow</td><td>1</td></tr>
# <tr><td>39</td><td>judicator - at the expense of humanity</td><td>1</td></tr>
# <tr><td>40</td><td>kamelot - haven</td><td>1</td></tr>
# <tr><td>41</td><td>the crinn - shadow breather</td><td>1</td></tr>
# <tr><td>42</td><td>ufomammut - ecate</td><td>1</td></tr>
# <tr><td>43</td><td>wilderun - sleep at the edge of the earth</td><td>1</td></tr>
# <tr><td>44</td><td>royal thunder - crooked doors</td><td>1</td></tr>
# <tr><td>45</td><td>tribulation - children of the night</td><td>1</td></tr>
# <tr><td>46</td><td>kêres - battle secrets</td><td>1</td></tr>
# <tr><td>47</td><td>kjeld - skym</td><td>1</td></tr>
# <tr><td>48</td><td>bell witch - four phantoms</td><td>1</td></tr>
# <tr><td>49</td><td>a sulphur aeon - gateway to the antisphere</td><td>1</td></tr>
# <tr><td>50</td><td>archgoat - the apocalyptic triumphator</td><td>1</td></tr>
# <tr><td>51</td><td>false - untitled</td><td>1</td></tr>
# <tr><td>52</td><td>solefald - worldmetal - kosmopolis sud</td><td>1</td></tr>
# <tr><td>53</td><td>vattnet viskar - settler</td><td>1</td></tr>
# <tr><td>54</td><td>hic iacet - the cosmic trance into void</td><td>1</td></tr>
# <tr><td>55</td><td>ancient wind - the chosen slain</td><td>1</td></tr>
# <tr><td>56</td><td>enforcer - from beyond</td><td>1</td></tr>
# <tr><td>57</td><td>gospel of the witches - salem's wounds</td><td>1</td></tr>
# <tr><td>58</td><td>skinless - only the ruthless remain</td><td>1</td></tr>
# <tr><td>59</td><td>napalm death - apex predator -- easy meat</td><td>1</td></tr>
# <tr><td>60</td><td>a secret revealed - the bleakness</td><td>1</td></tr>
# <tr><td>61</td><td>evil invaders - pulses of pleasure</td><td>1</td></tr>
# <tr><td>62</td><td>barren earth - on lonely towers</td><td>1</td></tr>
# <tr><td>63</td><td>perihelion - infinite decay</td><td>1</td></tr>
# <tr><td>64</td><td>macabre omen - gods of war - at war</td><td>1</td></tr>
# <tr><td>65</td><td>entrails - obliteration</td><td>1</td></tr>
# <tr><td>66</td><td>gruesome - savage land</td><td>1</td></tr>
# <tr><td>67</td><td>cendra - 666 bastards</td><td>1</td></tr>
# <tr><td>68</td><td>orden ogan - ravenhead</td><td>1</td></tr>
# <tr><td>69</td><td>arcane - known/learned</td><td>1</td></tr>
# <tr><td>70</td><td>carach angren - this is no fairytale</td><td>1</td></tr>
# <tr><td>71</td><td>die like gentlemen - five easy lies</td><td>1</td></tr>
# <tr><td>72</td><td>paganland - fatherland</td><td>1</td></tr>
# <tr><td>73</td><td>akhlys - the dreaming i</td><td>1</td></tr>
# <tr><td>74</td><td>clandestine blaze - new golgotha rising</td><td>1</td></tr>
#     </table>
